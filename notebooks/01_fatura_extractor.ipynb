# %%
# criando e habilitando ambiente virtual (venv)
# VERIFICAR SE ESTA NA PASTA RAIZ DO PROJETO
## Get-Location or pwd
# python -m venv venv
# .\venv\Scripts\Activate.ps1

# %%
# !pip install pandas pdfplumber openpyxl jupyter

print("Ambiente configurado com sucesso!")

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent
sys.path.append(str(ROOT))

# %%
from src.extrator import extrair_dados_pdf

# %%
#teste dados

dados = extrair_dados_pdf( ROOT / "data" / "raw" / "fatura.pdf" )

dados
# Out:
# {'ARQUIVO': 'fatura.pdf',
#  'SEGURADO': 'LAIS SOUZA DE OLIVEIRA BARROS',
#  'Nº PROCESSO': '2025000477319600',
#  'VALOR RECIBO': '494.20',
#  'NÚMERO DO CARTÃO': '773 245 003093 00 9',
#  'PROCEDIMENTO': 'Pequenos Atend. Ambulatoriais',
#  'DATA EVENTO': '25/10/2025',
#  'DATA PROTOCOLO': '31/10/2025',
#  'CPF': '107.922.347-90'}

# %%
import pandas as pd

# %%
#exportar dados

writer = pd.ExcelWriter(ROOT / "data" / "raw" / "out" / "fatura.xlsx", engine='openpyxl')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 3
#       1 #exportar dados
#       2
# ----> 3 writer = pd.ExcelWriter(ROOT / "data" / "raw" / "out" / "fatura.xlsx", engine='openpyxl')
#
# File c:\Users\Gustavo Belfort\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\excel\_openpyxl.py:62, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      58 from openpyxl.workbook import Workbook
#      60 engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
# ---> 62 super().__init__(
#      63     path,
#      64     mode=mode,
#      65     storage_options=storage_options,
#      66     if_sheet_exists=if_sheet_exists,
#      67     engine_kwargs=engine_kwargs,
#      68 )
# ...
