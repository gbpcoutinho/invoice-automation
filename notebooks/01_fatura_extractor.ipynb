# %%
# criando e habilitando ambiente virtual (venv)
# VERIFICAR SE ESTA NA PASTA RAIZ DO PROJETO
## Get-Location or pwd
# python -m venv venv
# .\venv\Scripts\Activate.ps1

# %%
# !pip install pandas pdfplumber openpyxl jupyter

print("Ambiente configurado com sucesso!")

# %%
# !pip freeze > ../requirements.txt

# usar pip freeze >requirements.txt se usar direto na bash

# %%
git config --global user.name "Gustavo Belfort"
git config --global user.email "gbpcoutinho@gmail.com"

# %%
Agora seu fluxo será esse

Sempre que fizer alguma alteração:

1. Veja o que mudou
git status
2. Adicione as alterações
git add .

ou, se quiser adicionar apenas um arquivo:

git add notebooks/01_fatura_extractor.ipynb
3. Faça um commit

Exemplo:

git commit -m "feat: implementa leitura de PDF com pdfplumber"
4. Envie para o GitHub
git push

Só isso.

# %%
from pathlib import Path

from src.extrator import extrair_dados_pdf

pdf = Path("../data/raw/fatura.pdf")

dados = extrair_dados_pdf(pdf)

dados
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pathlib import Path
#       2
# ----> 3 from src.extrator import extrair_dados_pdf
#       4
#       5 pdf = Path("../data/raw/fatura.pdf")
#       6
#
# ModuleNotFoundError: No module named 'src'
